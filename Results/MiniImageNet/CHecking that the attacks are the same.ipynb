# %%
import numpy as np
import pickle

# %%
L_inf = 0.05
with open('./GENE_'+str(L_inf)+'_15k.txt' , "rb") as fp:
    gene = pickle.load(fp)
with open('./COMBI_'+str(L_inf)+'.txt' , "rb") as fp:
    comb = pickle.load(fp)
with open('./BOBY_'+str(L_inf)+'_FINAL_linear.txt' , "rb") as fp:
    line = pickle.load(fp)
with open('./BOBY_'+str(L_inf)+'_FINAL_over.txt' , "rb") as fp:
    over = pickle.load(fp)

# %%
gene
# Out:
# [[561, 0, 1],
#  [221, 0, 2],
#  [491, 0, 3],
#  [1446, 0, 4],
#  [1306, 0, 5],
#  [4371, 0, 6],
#  [1021, 0, 7],
#  [2316, 0, 8],
#  [316, 0, 9],
#  [2331, 0, 1],
#  [196, 0, 2],
#  [221, 0, 3],
#  [3501, 0, 4],
#  [896, 0, 5],
#  [931, 0, 6],
#  [986, 0, 7],
#  [1011, 0, 8],
#  [191, 0, 9],
#  [726, 0, 1],
#  [401, 0, 2],
#  [501, 0, 3],
#  [1576, 0, 4],
#  [4431, 0, 5],
#  [4906, 0, 6],
#  [1511, 0, 7],
#  [5496, 0, 8],
#  [486, 0, 9],
#  [9226, 0, 1],
#  [356, 0, 2],
#  [7301, 0, 3],
#  [3176, 0, 4],
#  [4036, 0, 5],
#  [4326, 0, 6],
#  [1451, 0, 7],
#  [8166, 0, 8],
#  [2556, 0, 9],
#  [1296, 0, 1],
#  [191, 0, 2],
#  [2671, 0, 3],
#  [3136, 0, 4],
#  [4471, 0, 5],
#  [9456, 0, 6],
#  [1166, 0, 7],
#  [3696, 0, 8],
#  [966, 0, 9],
#  [7556, 0, 1],
#  [46, 0, 2],
#  [3296, 0, 3],
#  [511, 0, 4],
#  [14031, 0, 5],
#  [1966, 0, 6],
#  [601, 0, 7],
#  [2286, 0, 8],
#  [256, 0, 9],
#  [376, 0, 1],
#  [411, 0, 2],
#  [586, 0, 3],
#  [2126, 0, 4],
#  [1491, 0, 5],
#  [1346, 0, 6],
# ...

# %%
comb
# Out:
# [[1484, 0, array([1]), 0.8862172],
#  [171, 0, array([2]), -0.13416749],
#  [925, 0, array([3]), 0.82282245],
#  [1268, 0, array([4]), 0.7235966],
#  [1543, 0, array([5]), 0.9023803],
#  [1789, 0, array([6]), 1.5114008],
#  [1096, 0, array([7]), 0.8364287],
#  [2348, 0, array([8]), 1.5485116],
#  [818, 0, array([9]), 0.90079045],
#  [1162, 0, array([1]), 1.5163566],
#  [76, 0, array([2]), 0.80556506],
#  [321, 0, array([3]), 1.1407933],
#  [787, 0, array([4]), 1.459991],
#  [854, 0, array([5]), 1.5410074],
#  [220, 0, array([6]), 1.1598326],
#  [350, 0, array([7]), 1.4172635],
#  [470, 0, array([8]), 1.5589421],
#  [179, 0, array([9]), 0.7163485],
#  [842, 0, array([1]), 1.1534679],
#  [621, 0, array([2]), 0.5011232],
#  [940, 0, array([3]), 0.5616913],
#  [718, 0, array([4]), 0.5353701],
#  [2585, 0, array([5]), 1.3166033],
#  [2767, 0, array([6]), 1.4223106],
#  [940, 0, array([7]), 1.1657882],
#  [1204, 0, array([8]), 0.825861],
#  [627, 0, array([9]), 0.66641176],
# ...

# %%
line
# Out:
# [[1804, array(0), 1, 1.1220047],
#  [238, array(0), 2, -1.011141],
#  [2566, array(0), 4, 0.55379003],
#  [911, array(0), 5, 0.9934617],
#  [1975, array(0), 6, 1.4811125],
#  [849, array(0), 7, 0.87666035],
#  [1259, array(0), 8, 1.6451488],
#  [958, array(0), 9, 0.5684176],
#  [1205, array(0), 1, 1.4845355],
#  [244, array(0), 2, 0.8847934],
#  [607, array(0), 3, 1.3366998],
#  [2184, array(0), 4, 1.0333673],
#  [1135, array(0), 5, 1.5015063],
#  [417, array(0), 6, 0.9008262],
#  [851, array(0), 7, 1.2364352],
#  [1861, array(0), 8, 1.4136479],
#  [242, array(0), 9, 0.73865753],
#  [1290, array(0), 1, 1.0758101],
#  [670, array(0), 2, 0.30941623],
#  [1393, array(0), 3, 0.5553651],
#  [982, array(0), 4, 0.2092796],
#  [2971, array(0), 5, 1.2485781],
#  [3176, array(0), 6, 1.5619158],
#  [1282, array(0), 7, 0.7801486],
#  [2414, array(0), 8, 0.8939102],
#  [798, array(0), 9, 0.5711366],
#  [4367, array(0), 1, 1.0541224],
#  [487, array(0), 2, -0.009425877],
# ...
